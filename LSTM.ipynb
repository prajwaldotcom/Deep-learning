# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.6.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from datasets import load_dataset

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
dataset = load_dataset("dair-ai/emotion")

train_df = pd.DataFrame(dataset["train"])
test_df = pd.DataFrame(dataset["test"])

print(train_df.head())
# Out:
#                                                 text  label
# 0                            i didnt feel humiliated      0
# 1  i can go from feeling so hopeless to so damned...      0
# 2   im grabbing a minute to post i feel greedy wrong      3
# 3  i am ever feeling nostalgic about the fireplac...      2
# 4                               i am feeling grouchy      3

# %%
print(train_df.shape)
print(test_df.shape)

train_df['label'].value_counts()

(16000, 2)
(2000, 2)
# Out:
# (16000, 2)
# (2000, 2)
# (2000, 2)

# %%
emotion_names = {
    0:"sadness",
    1:"joy",
    2:"love",
    3:"anger",
    4:"fear",
    5:"surprise"
}

train_df["emotion"] = train_df["label"].map(emotion_names)
test_df["emotion"] = test_df["label"].map(emotion_names)

train_df.head()
# Out:
#                                                 text  label  emotion
# 0                            i didnt feel humiliated      0  sadness
# 1  i can go from feeling so hopeless to so damned...      0  sadness
# 2   im grabbing a minute to post i feel greedy wrong      3    anger
# 3  i am ever feeling nostalgic about the fireplac...      2     love
# 4                               i am feeling grouchy      3    anger

# %%
encoder = LabelEncoder()

y_train = encoder.fit_transform(train_df["emotion"])
y_test = encoder.transform(test_df["emotion"])

# %% [markdown]
# **Tokenization**

# %%
vocab_size = 10000

tokenizer = Tokenizer(num_words=vocab_size,
                      oov_token="")

tokenizer.fit_on_texts(train_df["text"])

# %% [markdown]
# **Converting tokens to sequence**

# %% [markdown]
# **Padding**

# %%
X_train = tokenizer.texts_to_sequences(train_df["text"])
X_test = tokenizer.texts_to_sequences(test_df["text"])

# %% [markdown]
# **Building the model**

# %%
max_length = max([len(x) for x in X_train])

X_train_padded = pad_sequences(X_train, maxlen=max_length, padding='post')
X_test_padded = pad_sequences(X_test, maxlen=max_length, padding='post')

model = Sequential()

model.add(
    Embedding(input_dim=vocab_size,
              output_dim=64)
)

model.add(
    LSTM(64)
)

model.add(
    Dropout(0.5)
)

model.add(
    Dense(32, activation="relu")
)

model.add(
    Dense(6, activation="softmax")
)

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Compiling the model**

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# **Training the model**

# %%
history = model.fit(
    X_train_padded,
    y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64
)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.3373 - loss: 1.5771 - val_accuracy: 0.3262 - val_loss: 1.5742
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.3374 - loss: 1.5776 - val_accuracy: 0.3262 - val_loss: 1.5735
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.3376 - loss: 1.5764 - val_accuracy: 0.3262 - val_loss: 1.5728
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.3383 - loss: 1.5756 - val_accuracy: 0.3250 - val_loss: 1.5754
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - accuracy: 0.3385 - loss: 1.5744 - val_accuracy: 0.3244 - val_loss: 1.5757
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.3394 - loss: 1.5718 - val_accuracy: 0.3253 - val_loss: 1.5747
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.3405 - loss: 1.5694 - val_accuracy: 0.3250 - val_loss: 1.5752
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.3404 - loss: 1.5671 - val_accuracy: 0.3259 - val_loss: 1.5756
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.3404 - loss: 1.5389 - val_accuracy: 0.3316 - val_loss: 1.5291
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.3870 - loss: 1.3728 - val_accuracy: 0.4003 - val_loss: 1.3057
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.4688 - loss: 1.1580 - val_accuracy: 0.4916 - val_loss: 1.2100
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.6609 - loss: 0.8974 - val_accuracy: 0.6284 - val_loss: 1.0822
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.7747 - loss: 0.6721 - val_accuracy: 0.7294 - val_loss: 0.8789
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8257 - loss: 0.5426 - val_accuracy: 0.6997 - val_loss: 0.9019
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.8577 - loss: 0.4668 - val_accuracy: 0.7250 - val_loss: 0.8966
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.8813 - loss: 0.4052 - val_accuracy: 0.7231 - val_loss: 0.8853
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9063 - loss: 0.3450 - val_accuracy: 0.7337 - val_loss: 0.9638
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.9187 - loss: 0.3006 - val_accuracy: 0.7278 - val_loss: 0.9690
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9241 - loss: 0.2762 - val_accuracy: 0.7300 - val_loss: 1.0017
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - accuracy: 0.9295 - loss: 0.2641 - val_accuracy: 0.7366 - val_loss: 1.0485
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9358 - loss: 0.2393 - val_accuracy: 0.7350 - val_loss: 1.0750
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9429 - loss: 0.2196 - val_accuracy: 0.7134 - val_loss: 1.1582
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - accuracy: 0.9477 - loss: 0.2048 - val_accuracy: 0.7006 - val_loss: 1.2540
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9493 - loss: 0.1998 - val_accuracy: 0.7397 - val_loss: 1.1014
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.9508 - loss: 0.1974 - val_accuracy: 0.7369 - val_loss: 1.0739
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9588 - loss: 0.1695 - val_accuracy: 0.7478 - val_loss: 1.1805
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.9566 - loss: 0.1735 - val_accuracy: 0.7462 - val_loss: 1.2502
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 0.9527 - loss: 0.1816 - val_accuracy: 0.7325 - val_loss: 1.1745
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9554 - loss: 0.1744 - val_accuracy: 0.7403 - val_loss: 1.2144
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9590 - loss: 0.1650 - val_accuracy: 0.7437 - val_loss: 1.1720
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9625 - loss: 0.1491 - val_accuracy: 0.7528 - val_loss: 1.1674
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.9641 - loss: 0.1430 - val_accuracy: 0.7300 - val_loss: 1.3697
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - accuracy: 0.9672 - loss: 0.1370 - val_accuracy: 0.7431 - val_loss: 1.2431
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.9640 - loss: 0.1376 - val_accuracy: 0.7378 - val_loss: 1.3380
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9606 - loss: 0.1514 - val_accuracy: 0.7406 - val_loss: 1.3559
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.9588 - loss: 0.1567 - val_accuracy: 0.7278 - val_loss: 1.3758
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.9601 - loss: 0.1565 - val_accuracy: 0.7484 - val_loss: 1.2159
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.9651 - loss: 0.1357 - val_accuracy: 0.7469 - val_loss: 1.2566
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9663 - loss: 0.1309 - val_accuracy: 0.7531 - val_loss: 1.3175
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9670 - loss: 0.1259 - val_accuracy: 0.7475 - val_loss: 1.3962
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 50ms/step - accuracy: 0.9671 - loss: 0.1262 - val_accuracy: 0.7347 - val_loss: 1.4229
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.9645 - loss: 0.1324 - val_accuracy: 0.7553 - val_loss: 1.3101
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9670 - loss: 0.1269 - val_accuracy: 0.7547 - val_loss: 1.3038
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.9659 - loss: 0.1244 - val_accuracy: 0.7469 - val_loss: 1.3712
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.9705 - loss: 0.1098 - val_accuracy: 0.7447 - val_loss: 1.3536
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.9691 - loss: 0.1120 - val_accuracy: 0.7412 - val_loss: 1.3654
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.9667 - loss: 0.1224 - val_accuracy: 0.7325 - val_loss: 1.4984
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9693 - loss: 0.1092 - val_accuracy: 0.7391 - val_loss: 1.4272
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9677 - loss: 0.1226 - val_accuracy: 0.7250 - val_loss: 1.3620
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.9681 - loss: 0.1117 - val_accuracy: 0.7356 - val_loss: 1.4120

# %% [markdown]
# **Accuracy Plot**

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Validation")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")

plt.legend()
plt.show()

# %% [markdown]
# **Loss Plot**

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Validation")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")

plt.legend()
plt.show()

# %% [markdown]
# **Evaluation Of Model**

# %%
loss, accuracy = model.evaluate(X_test_padded, y_test)

print("Test Accuracy :", accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3475 - loss: 1.5597
# Test Accuracy : 0.3474999964237213

# %% [markdown]
# **Classification Model**

# %%
pred = model.predict(X_test_padded)

pred_classes = np.argmax(pred, axis=1)

print(classification_report(y_test, pred_classes))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       275
#            1       0.00      0.00      0.00       224
#            2       0.35      1.00      0.52       695
#            3       0.00      0.00      0.00       159
#            4       0.00      0.00      0.00       581
#            5       0.00      0.00      0.00        66
#
#     accuracy                           0.35      2000
#    macro avg       0.06      0.17      0.09      2000
# weighted avg       0.12      0.35      0.18      2000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **Predicting your own sentence**

# %%
sentence = ["i didnt feel sad"]

seq = tokenizer.texts_to_sequences(sentence)
seq = pad_sequences(seq, maxlen=max_length, padding="post")

prediction = model.predict(seq)

emotion = encoder.inverse_transform([np.argmax(prediction)])

print("Predicted Emotion:", emotion[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted Emotion: sadness
